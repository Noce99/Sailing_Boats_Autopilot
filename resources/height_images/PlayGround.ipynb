# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Only for jupyter notebook visualization
# %matplotlib inline

# %%
image = cv2.imread("Untitled-3.png", cv2.IMREAD_GRAYSCALE)
clored_image = cv2.imread("Untitled-3.png")

# %%
plt.imshow(image, cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
image.max()
# Out:
# 255

# %%
image.min()
# Out:
# 0

# %%
np.sum(image == 0)
# Out:
# 27325693

# %%
np.sum(image != 0)
# Out:
# 39783171

# %%
clored_image[image == 0] = np.array([255, 0, 0])
clored_image[image != 0] = np.array([0, 255, 0])

# %%
plt.imshow(clored_image)
plt.show()
